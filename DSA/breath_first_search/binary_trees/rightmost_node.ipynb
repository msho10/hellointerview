# %% [markdown]
# ### DESCRIPTION (inspired by Leetcode.com)
# medium
#
# Given the root of a binary tree, return the rightmost node at each level of the tree. The output should be a list containing only the values of those nodes.
#
# Example 1:
#
# Input:[1, 3, 4, null, 2, 7, null, 8]
#
# Output: [1, 4, 7, 8]
#
# Example 2:
#
# Input: [1,2,5,3,null,null,null,null,4]
#
# Output: [1, 5, 3, 4]

# %%
from collections import deque 
class TreeNode:
    def __init__(self, val: int, left: 'TreeNode' = None, right: 'TreeNode' = None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def rightmostNode(self, root: TreeNode) -> list[int]:
        if not root:
            return []
        
        def visit_node():
            node = queue.popleft()
            if node.left:
                queue.append(node.left)
            if node.right:
                queue.append(node.right)
            return node
            
        result = []
        queue = deque([root])
            
        while queue:
            level_len = len(queue)
            for _ in range(level_len - 1):
                visit_node()

            node = visit_node()  
            result.append(node.val)

        return result

# %% [markdown]
# ### Feedback
#
# Your solution is correct and passes the tests. The BFS correctly captures each level’s final node, including skewed and single-node trees, and returns [] for an empty tree. visit_node() cleanly centralizes dequeuing and child enqueuing. Complexity is optimal: O(n) time and O(w) space, where w is the maximum width.
#
# For interview readability, you could make the intent slightly more direct by processing all level_len nodes in one loop and appending when the index is the last; your current level_len - 1 plus one separate call is valid, but requires the reader to verify that exactly level_len nodes are consumed.

# %%
from collections import deque 
class TreeNode:
    def __init__(self, val: int, left: 'TreeNode' = None, right: 'TreeNode' = None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def rightmostNode(self, root: TreeNode) -> list[int]:
        if not root:
            return []
        
        def visit_node():
            node = queue.popleft()
            if node.left:
                queue.append(node.left)
            if node.right:
                queue.append(node.right)
            return node
            
        result = []
        queue = deque([root])
            
        while queue:
            level_len = len(queue)
            for i in range(level_len):
                node = visit_node()
                if i == level_len - 1:
                    result.append(node.val)

        return result

# %%
from typing import Callable

class Input:
    def __init__(self, nums: list[int]):
        self.nums = nums
        
class Test:  
    def __init__(self, input: Input, result: list[int]):
        self.input = input
        self.expected_result = result
        self.root = self._createNodefromList(input.nums, 0)

    def _createNodefromList(self, nums: list[int], index: int) -> TreeNode:
        if index >= len(nums) or nums[index] is None:
            return None
        newNode = TreeNode(nums[index])
        newNode.left = self._createNodefromList(nums, 2*index+1)
        newNode.right = self._createNodefromList(nums, 2*index+2)
        return newNode

def run_tests(tests: list[Test], func: Callable[[TreeNode], list[int]]):
    for test in tests:
        result = func(test.root)
        if result == test.expected_result:
            print(f"Test passed for {test.input.nums}")
        else:
            print(f"Test failed for {test.input.nums}. Expected: {test.expected_result}, Actual: {result}")

# %%
tests = [
    Test(Input([]), []),
    Test(Input([1]), [1]),
    Test(Input([1,2]), [1,2]),
    Test(Input([1,2,3]), [1,3]),
    Test(Input([1, 3, 4, None, 2, 7, None, None, None, 8]), [1, 4, 7, 8]),
    Test(Input([1, 2, 5, 3, None, None, None, None, 4]), [1, 5, 3, 4])
]

run_tests(tests, Solution().rightmostNode)
# Out:
# Test passed for []
# Test passed for [1]
# Test passed for [1, 2]
# Test passed for [1, 2, 3]
# Test passed for [1, 3, 4, None, 2, 7, None, None, None, 8]
# Test passed for [1, 2, 5, 3, None, None, None, None, 4]
